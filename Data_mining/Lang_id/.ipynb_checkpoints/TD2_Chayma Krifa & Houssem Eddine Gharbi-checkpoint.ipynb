# %% [markdown]
# # Language Identification

# %% [markdown]
# **Outline:**
# 1. Read raw data
# 2. Clean data
# 3. Try existing language identification libraries
# 4. Construct our own dictionary-based language classifier
# 5. Construct our own language classifier using supervised learning
#
# **What you need to do:**
# - Read and execute the source code below and answer the questions in **EXERCISE 1 - EXERCISE 6**.
# - **Submit** the modifiled file ``TD2.ipynb`` on google drive.

# %%
import pandas as pd
import numpy as np

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# set the font size of plots
plt.rcParams['font.size'] = 14

# %%
np.set_printoptions(precision=3)

# %% [markdown]
# ## Read raw data

# %%
corpus_files = ['langid_data_TUN-AR.txt', 'langid_data_ARA.txt']

# %%
def read_text_file(filename):
    print('Reading file ' + filename + "...")
    with open(filename, "r", encoding='utf8') as textfile:
        L = []
        for line in textfile:
            L.append(line.strip())
        print('File contains ', len(L), "lines.\n")
        return L

# %%
tun_corpus = read_text_file(corpus_files[0])
ara_corpus = read_text_file(corpus_files[1])
# Out:
# Reading file langid_data_TUN-AR.txt...
# File contains  13932 lines.
#
# Reading file langid_data_ARA.txt...
# File contains  21787 lines.

# %% [markdown]
# ## Text Cleaning
# For language identification, we usually only need to remove non-word characters and replace them with spaces. But since our corpus contains social media text, a few other operations are necessary.
#
# - Remove non-word symbols (punctuation, math symbols, emoticons, URLs, hashtags, etc.).
# - Replace punctuation and white space with a single space.
# - Normalize word elongations and word repetitions.
# - Remove documents that contain a large fraction of latin characters (some documents contain english or french words).
# - Remove very short documents.

# %%
import re

# regexp for word elongation: matches 3 or more repetitions of a word character.
two_plus_letters_RE = re.compile(r"(\w)\1{1,}", re.DOTALL)
three_plus_letters_RE = re.compile(r"(\w)\1{2,}", re.DOTALL)
# regexp for repeated words
two_plus_words_RE = re.compile(r"(\w+\s+)\1{1,}", re.DOTALL)


def cleanup_text(text):
    # Remove URLs
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', '', text)

    # Remove user mentions of the form @username
    text = re.sub('@[^\s]+', '', text)
    
    # Replace special html-encoded characters with their ASCII equivalent, for example: &#39 ==> '
    #if re.search("&#",text):
       # text = html.unescape(text)

    # Remove special useless characters such as _x000D_
    text = re.sub(r'_[xX]000[dD]_', '', text)

    # Replace all non-word characters (such as emoticons, punctuation, end of line characters, etc.) with a space
    text = re.sub('[\W_]', ' ', text)

    # Remove redundant white spaces
    text = text.strip()
    text = re.sub('[\s]+', ' ', text)

    # normalize word elongations (characters repeated more than twice)
    text = two_plus_letters_RE.sub(r"\1\1", text)

    # remove repeated words
    text = two_plus_words_RE.sub(r"\1", text)

    return text

# unit test of this function
cleanup_text("This is just a simple. js .... jshd)jhsd__js--dh \n\n asjh\n test !!")
# Out:
# 'This just a simple js jshd jhsd js dh asjh test'

# %% [markdown]
# ### EXERCISE 1
#
# Do the following operations for **each** corpus. Store the new corpora in new variables called ``tun_corpus_clean`` and ``ara_corpus_clean``
# 1. Clean up each document in the corpus using the ``cleanup_text`` function given above.
# 2. Remove all documents that contain a large fraction of latin characters (for example more than 70%).  **Hint**: use a regular expression with pattern [a-zA-Z]
# 3. Remove very short documents (containing less than 10 characters, for e.g.).
# 4. Display the number of documents in the clean corpus.

# %%
## COMPLETE THE CODE BELOW

##Question1:    
tun_corpus_clean= [cleanup_text(doc) for doc in tun_corpus]
ara_corpus_clean= [cleanup_text(doc1) for doc1 in ara_corpus]
##Question2 and 3:
tun_corpus_clean_NLatin=[]

for doc in tun_corpus_clean:
     if(((len(" ".join(re.split('[^a-zA-Z]*',doc)))-1)/len(doc))*100 <70 and (len(doc)> 10)):
            tun_corpus_clean_NLatin.append(doc)
            
ara_corpus_clean_NLatin=[]
for doc in ara_corpus_clean:
     if(((len(" ".join(re.split('[^a-zA-Z]*',doc)))-1)/len(doc))*100 <70 and (len(doc)> 10)):
            ara_corpus_clean_NLatin.append(doc)
            
##Question4:


tun_corpus_clean=  tun_corpus_clean_NLatin
ara_corpus_clean=  ara_corpus_clean_NLatin


print(len(tun_corpus_clean), len(ara_corpus_clean))
# Out:
# /anaconda3/lib/python3.6/re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)
# 12039 21293

# %% [markdown]
# ## Try existing language identification libraries
# - In TD1, we used NLTK's textcat library.
# - In this TD, we will use another 2 libraries (``langdetect`` and ``langid``) which are actually more accurate than ``textcat``. However, as you will see they

# %% [markdown]
# ### Load special libraries for language identification

# %%
test_doc = "This is just a simple test !!"

# %%
# langdetect library

import langdetect
from langdetect.lang_detect_exception import LangDetectException

try:
    res = langdetect.detect_langs(test_doc)   # LANGDETECT
    #res = langdetect.detect(test_doc) 
except LangDetectException:
    res = langdetect.language.Language("UNK",0)
res
# Out:
# [en:0.9999959084653124]

# %%
# langid library

from langid.langid import LanguageIdentifier, model
li = LanguageIdentifier.from_modelstring(model, norm_probs=True)
print(li.classify(test_doc)[0])
# print(li.rank(test_doc)[0:3])
# Out:
# en

# %%
# NLTK textcat library - JUST IN CASE
from nltk.classify.textcat import TextCat

# create class instance
tc = TextCat()
tc.guess_language(test_doc)
# Out:
# 'eng'

# %% [markdown]
# ### Test ``langdetect`` on a small sample of Tunisian Corpus

# %%
# Select a small random sample of 5000 documents from the corpus
n = 5000
random_indices = np.random.choice(np.arange(len(tun_corpus_clean)), n, replace=False)
small_corpus = [tun_corpus_clean[i] for i in random_indices]

# %%
res_langdetect = []

for doc in small_corpus:
    try:
        res_langdetect.append(langdetect.detect_langs(doc))
    except LangDetectException:
        res_langdetect.append([langdetect.language.Language("UNK",0)])

# %%
len(small_corpus),len(res_langdetect)
# Out:
# (5000, 5000)

# %% [markdown]
# ### Visualize results

# %%
# Let's put the results in a data frame for ease of manipulation

def foo1(x):
    u = str(x).split(':')
    return [u[0],float(u[1])]
L = [[small_corpus[i]]+foo1(x[0]) for i,x in enumerate(res_langdetect)]
df = pd.DataFrame(L)
df.columns = ['document', 'language','probability']
df.head()
# Out:
#                                  document language  probability
# 0  يا سي امير راك ماسط ماتضحكش جملا والله       ar     0.999998
# 1                    موزايك تمويل اماراتي       ar     0.999996
# 2                 انا من دزاير توحشنااكمم       ar     0.999998
# 3                       اعز و احلي و احسن       ar     0.999997
# 4            متاكدة الي بش يطيح عليهم لكل       ar     0.999998

# %% [markdown]
# ### EXERCISE 3
# 1. Plot the distribution of languages (call value_counts() on the ``language`` column of ``df``)
# 2. Plot the histogram of probabilities (call plot(kind='hist') on the ``probability`` column of ``df``)
# 3. What are the top 2 languages identified in this corpus?
# 4. For what fraction of documents is this language identifier more than 80% confident in its decision? (i.e. probability > 0.8)

# %% [markdown]
# ENTER YOUR ANSWERS BELOW
#
# ...
#
# ...

# %%
## ENTER YOUR SOURCE CODE BELOW
##Question1:
df.language.value_counts().plot(kind="bar")

# %%
##Question2:
df.probability.plot(kind="hist")

# %%
##Question3: Top 2 languages identified in the corpus: Arabic and French

# %%
df.shape
# Out:
# (5000, 3)

# %%
#Question4:
df[df.probability>0.8].shape
# Out:
# (4888, 3)

# %% [markdown]
# ### EXERCISE 4 (homework - skip this during class)
#
# 1. Test both libraries (``langdetect`` and ``langid``) on the **entire** ``ara_corpus_clean`` corpus.
# 2. Which library seems to be more accurate for the Arabic language? Justify based on visual inspection of the results.
# 3. Design a new language identification method that combines both libraries -- basically just use the result corresponding to the higher probability.
# 4. Is this new method more accurate than the individual methods? Again, justify your answer based on visual inspection of the results.

# %%
n = 5000
random_indices = np.random.choice(np.arange(len(ara_corpus_clean)), n, replace=False)
small_corpus = [ara_corpus_clean[i] for i in random_indices]
res_langdetect = []

# for doc in small_corpus:
#     try:
#         res_langid.append(li.classify(doc))
#     except LangDetectException:
#         res_langid.append([langdetect.language.Language("UNK",0)])     
for doc in small_corpus:
    try:
        res_langdetect.append(langdetect.detect_langs(doc))
    except LangDetectException:
        res_langdetect.append([langdetect.language.Language("UNK",0)])        
L = [[small_corpus[i]]+foo1(x[0])+[li.classify(small_corpus[i])[0],li.classify(small_corpus[i])[1]] for i,x in enumerate(res_langdetect)]
df1 = pd.DataFrame(L)
df1.columns = ['document', 'language_Langdetect','probability_langdetect','language_Langid', 'probability_langid']
df1.head()
# Out:
#                                             document language_Langdetect  \
# 0  بل الف نجمه ع هالعبه انصح كل من يحب الدقه والس...                  ar
# 1  منتج ممتاز وتغليف رائع وصوت نقي مميز وواضح وقو...                  ar
# 2  فندق hellzooaaguara الأسوأ أننا جربنا ثلاث غرف...                  ar
# 3  انا جربتهم بتنظيف الاسنان ومانو بصراحة يجننو ب...                  ar
# 4  بصراحة قاعة الافراح لم تعجبني بسبب انها موزعة ...                  ar
#
#    probability_langdetect language_Langid  probability_langid
# 0                0.999999              ar                 1.0
# 1                0.999997              ar                 1.0
# 2                0.999999              ar                 1.0
# 3                0.999998              ar                 1.0
# 4                0.999998              ar                 1.0

# %% [markdown]
# ******

# %%
df1
# Out:
#                                                document language_Langdetect  \
# 0     بل الف نجمه ع هالعبه انصح كل من يحب الدقه والس...                  ar
# 1     منتج ممتاز وتغليف رائع وصوت نقي مميز وواضح وقو...                  ar
# 2     فندق hellzooaaguara الأسوأ أننا جربنا ثلاث غرف...                  ar
# 3     انا جربتهم بتنظيف الاسنان ومانو بصراحة يجننو ب...                  ar
# 4     بصراحة قاعة الافراح لم تعجبني بسبب انها موزعة ...                  ar
# 5     موقع متوسط و غرف متوسطة لقد مكثت في هذا الفندق...                  ar
# 6     جيد جدا حديقة الحيوان مسلية جدا شوفت فيه الحيو...                  ar
# 7     النظافة عنوانهم ابد ما قد شفت نظافة مثل النظاف...                  ar
# 8     فندق جميل جدا في أسوان لقد مكثنا في هذا الفندق...                  ar
# 9     طبعا الكل بعرف كيف كان الطازج من أول ما فتح كل...                  ar
# 10    علبه الساعة دائما تغلف بشريط لاصق لونه بني وهو...                  ar
# 11                          قريبة من البيت واسعاها جيدة                  ar
# 12    حلو اذا كان غير مزحوم فندق رائع من حيث الموقع ...                  ar
# 13    ممتاز فندق عظيم غرفه نظيفة والطاقم ودود جد ا و...                  ar
# 14    يبيع اللوحات الفنية و البراويز و غيرها من الأش...                  ar
# 15    لم يعجبني وكان ينبغي أن يكون مع ساندويتش بـ 20...                  ar
# 16    اسوأ فندق رحته فى حياتى والله بدون مبالغه دا ا...                  ar
# 17    قبل سنة واحدة مطعم يعد الافضل بين المطاعم السو...                  ar
# 18    فندق لطيف الموقع رائع فريق العمل معظمه متعاون ...                  ar
# 19    تسجيل كلمة شكر لجمع افراد الفندق اول شئ الاسكن...                  ar
# 20    صناعه رديئه ولا تحتمل الاستعمال ابدا ولن انصح ...                  ar
# 21    فندق رائع نزلت في فندق الشيخ علي دهب رز ورت با...                  ar
# 22    فندق ذات موقع متميز الفندق بحق مكان رائع للإقا...                  ar
# 23    حسب خبرتي في المطاعم هذا من اسوء المطاعم اللي ...                  ar
# 24    لم أكرهه فهو لا يعد فندق ذو 4 نجوم الشيء الجيد...                  ar
# 25                                منتج ممتاز تركيز عالي                  ar
# 26                                   بصراحه ممتاز وفعال                  ar
# 27    غرف كريهة الرائحة لا تقم هنا أبدا لم أحصل على ...                  ar
# 28    المملكة العربية السعودية الخدمة ممتازة خصوصا م...                  ar
# 29    آه مكان روعة وراحة فيه مابعدها راحه غير الخدما...                  ar
# ...                                                 ...                 ...
# 4970  الحين الصيف جى واكيد الايس الكؤيم له مذاق خاص ...                  ar
# 4971  رائع أقمت فقط هنا لليلة واحدة كان الموظفون ودو...                  ar
# 4972  بامكاني ان اضيفه الى كريمات الترطيب وال حمامات...                  ar
# 4973  مرحبا بالسعادة موقع مميز وفريد اقامة كاملة وسع...                  ar
# 4974  موقع جيد غرف وحمامات صغيرة نزلت في فندق باتونغ...                  ar
# 4975  غالي والحقيقه اكله عادي والمشروبات بفلوس مع ان...                  ar
# 4976  ممتع ولكن ليس أربع نجوم وصلت أنا وخطيبي إلى ال...                  ar
# 4977  جيد جدا انا شخصيا استمتع بالتسوق في محلات اكسس...                  ar
# 4978  فندق ممتاز قضيت الفترة من 24 28 4 هناك وكانت ا...                  ar
# 4979         ممتاز يوقف التساقط ويطول حل جميع مشاكل شعر                  ar
# 4980  فندق مكة المكرمة ذو المكانة المرموقة يقع هذا ا...                  ar
# 4981  الفندق رائع جدا موقعه مميز للغايه فهو الفندق ر...                  ar
# 4982  اكثر من رائع فندق اكثر من را ئع من حيث الاستقب...                  ar
# 4983  هي مدرسة من اهم المدارس في ابوحليفة في الكويت ...                  ar
# 4984  ملاحظات عامة للفندق اقامة لا بأبس عدا عن مستوى...                  ar
# 4985  اوحش كافيه في مدينتي و غالي عالفاضي و نص ساعه ...                  ar
# 4986  الحرم مره أخرى عدنا إلى فندق الحرم هذا العام ف...                  ar
# 4987  قسم الفندق الخارجي جيد غرفة عادية طاقم عمل سيء...                  ar
# 4988  أقامة لاتوصف اقامة في فندق الخبر مريديان وقد ك...                  ar
# 4989                 إيجابيات و سلبيات مشد لتنحيف الجسم                  ar
# 4990  جيد جدا بدك توصل الكورنيش و بعدين تدور على صفة...                  ar
# 4991  فندق شيراتون دريم لاند لقد كنت من رواد الفندق ...                  ar
# 4992  شيء سخيف أود فقط أن أوجه انتباهكم إلى ما يلي إ...                  ar
# 4993                 هذه افضل لعبة سباق لعبتها في حياتي                  ar
# 4994  أول زيارة لمصر سافرنا كزوجين في يناير وأقمنا ف...                  ar
# 4995  لن أكرر ذلك مرة أخرى أبدا بقينا عالقين في مدري...                  ar
# 4996  فندق رائع على الواجهة البحرية لقد عدت للتو بعد...                  ar
# 4997  في البداية وجدت صعوبة في تحديد اللغة ثم بات كل...                  ar
# 4998  موقع رائع وخدمة سيئة اقمت في هذا الفندق يوم وا...                  ar
# 4999  لن أقيم هنا مرة أخرى المقبس الكهربائي في الغرف...                  ar
#
#       probability_langdetect language_Langid  probability_langid
# 0                   0.999999              ar            1.000000
# 1                   0.999997              ar            1.000000
# 2                   0.999999              ar            1.000000
# 3                   0.999998              ar            1.000000
# 4                   0.999998              ar            1.000000
# 5                   0.999999              ar            1.000000
# 6                   0.999999              ar            1.000000
# 7                   0.999998              ar            1.000000
# 8                   0.999997              ar            1.000000
# 9                   0.999998              ar            1.000000
# 10                  0.999997              ar            1.000000
# 11                  0.999998              ar            0.999989
# 12                  0.999996              ar            1.000000
# 13                  0.999999              ar            1.000000
# 14                  0.999999              ar            1.000000
# 15                  1.000000              ar            1.000000
# 16                  0.999996              ar            1.000000
# 17                  0.999997              ar            1.000000
# 18                  0.999999              ar            1.000000
# 19                  0.999999              ar            1.000000
# 20                  0.999998              fa            0.999999
# 21                  0.999998              ar            1.000000
# 22                  0.999998              ar            1.000000
# 23                  0.999999              ar            1.000000
# 24                  0.999998              ar            1.000000
# 25                  0.999997              ar            0.992960
# 26                  0.999998              fa            0.928890
# 27                  0.999998              ar            1.000000
# 28                  0.999999              ar            1.000000
# 29                  0.999998              ar            1.000000
# ...                      ...             ...                 ...
# 4970                0.999998              ar            1.000000
# 4971                0.999999              ar            1.000000
# 4972                0.999999              ar            1.000000
# 4973                0.999998              ar            1.000000
# 4974                0.999997              ar            1.000000
# 4975                0.999997              ar            1.000000
# 4976                1.000000              ar            1.000000
# 4977                0.999999              ar            1.000000
# 4978                0.999998              ar            1.000000
# 4979                0.999998              ar            0.999995
# 4980                0.999999              ar            1.000000
# 4981                1.000000              ar            1.000000
# 4982                0.999999              ar            1.000000
# 4983                0.999997              ar            1.000000
# 4984                0.999999              ar            1.000000
# 4985                0.999996              ar            1.000000
# 4986                0.999999              ar            1.000000
# 4987                0.999997              ar            1.000000
# 4988                0.999999              ar            1.000000
# 4989                0.999997              ar            0.999999
# 4990                0.999999              ar            1.000000
# 4991                0.999998              ar            1.000000
# 4992                0.999999              ar            1.000000
# 4993                0.999999              ar            0.999998
# 4994                0.999997              ar            1.000000
# 4995                1.000000              ar            1.000000
# 4996                0.999998              ar            1.000000
# 4997                0.999999              ar            1.000000
# 4998                0.999997              ar            1.000000
# 4999                0.999997              ar            1.000000
#
# [5000 rows x 5 columns]

# %%
df1.language_Langdetect.value_counts().plot(kind="bar")

# %%
df1.probability_langdetect.plot(kind="hist")

# %%
#Question4: Yes this method is more accurate than the seperate ones(look to cells above)

# %% [markdown]
# ## Construct a dictionary-based language classifier
# - **Step 1**: Divide each corpus into a training corpus (70%) and test corpus (30%).
# - **Step 2**: learn a set of typical words (also called stop words) of **every language** (TUN and ARA) based on its training corpus.
# - **Step 3**: create a language identification algorithm that takes the list of typical words of each language and a new document as input; and returns the language of this document as output.
# - **Step 4**: Evaluate the performance of this algorithm based on the test corpus -- calculate classification accuracy, precision, recall, F1, and confusion matrix.

# %% [markdown]
# ### EXERCISE 5
# Implement each step by following the instructions in the comments below.

# %%
# Step 1   COMPLETE THE CODE BELOW

from sklearn.model_selection import train_test_split
#?train_test_split

tun_corpus_clean_train, tun_corpus_clean_test = train_test_split(tun_corpus_clean,test_size=0.3 )

ara_corpus_clean_train, ara_corpus_clean_test = train_test_split(ara_corpus_clean,test_size=0.3)

# %%
ara_corpus_clean_test
# Out:
# ['عجبتنى Like',
#  'شلالات قريبة من المدينة الشلالات قريبة من انطاليا وجميلة تستطيع النزول الى الاسفل والدخول في المغارات الكثيرة ويمكنك تناول القهوة في الاسفل في احد الاكشاك الرائعة التي تقع على مجرى الشلال والافضل الذهاب مبكرا في الصباح لتفادي الزحام المزعج',
#  'لم يخذلنا أقمنا هنا للاحتفال بعيد ميلاد زوجي ال 40 حصلنا على غرفة رائعة وواسعة وجميلة في المبنى الأحدث لم أنزعج بسبب هذا الأمر بالرغم من أن الديكورات كانت ذات ألوان أفتح من تلك العادية في مالميزون غرفة جانبية بحجم مناسب تضم نافذتين كبيرتين وسرير ضخم اخترنا تناول وجبة الإفطار في الغرفة كونتيننتال كانت ضخمة أيضا كان يمكننا بالفعل الاشتراك في وجبة واحدة بدلا من وجبة لكل واحد منا قضينا كل وقت الصباح في تناولها هادئ جدا بحيث تحصل على ليلة نوم عميق في سرير مريح الموقع في ليث التي بها بارات جميلة ومطاعم على رصيف الميناء ثم ركبنا الحافلة رقم 16 أو 22 من نهاية الشارع والتي أخذتنا لأدنبرج تعمل الحافلة رقم 22 طوال الليل ومن شارع برينسيس وتناولنا الغداء في ذا ويتشري بجانب ذا كاسل الذي أود أيضا أن أوصي بها بشدة سنقيم فيه مرة أخرى',
#  'فندق حديث فى وسط العاصمة اقمت بالفندق 3 ليال من 12 6 2014 الفندق حديث و عصرى الغرف ممتازة و لكنها صغير الى حد ما الافطار جيدجدا يوجد انترنت مجانى داخل الفندق بالاضافة الى مقهى مجانى للانترنت الموظفين متعاونين فندق ممتاز لمن يبحث عن فندق داخل العاصمة و ليس منتجع للاسترخاء',
#  'هدا المحل بشارع سلوى و مستحيل تلاقي مكان تصف سيارتك بس مكان مرتب و بقدم قهوة و شاي كيك و ديكوراته عصرية و ملفته و بصراحة مكان مناسب للدراسة و في انترنت و في طابق ثاني كتير رايق و هادي',
#  'فندق رائع الفندق غاية فى الروعة والجمال الحدائق بالفعل حدائق سلطانية ويوجد اهتمام كبير بها الفندق نظيف والغرف نظيفة وممتازة وخصوصا المطلة على الشاطئ جميل ورائع لمحبى رياضة الغطس او ال snorkling لأن الشاطئ يقع على هضبة مرجانية ان صح التعبير طاقم العمل ممتاز جدا ومحترفين ويقدمون خدمة فندقية رائعة فريق الانيميشن ممتاز ويقدم عروض رائعة الملحوظة الوحيدة على الفندق هو ضعف اتصال الانترنت المجانى باللوبى وانصح من يزور شرم الشيخ عموما أن يحصل على USB Internet Connector نظرا لغلاء تسعيرة الانترنت بالفنادق عموما مع تحياتى احمد شاهين',
#  'ممتع ولكن ليس أربع نجوم وصلت أنا وخطيبي إلى المملكة المتحدة بعد قضاء عشر ليال شاملة الإقامة هنا الموظفين ودودين ويريدون دوما مساعدتك الطعام كان جيدا ليومين ثم أصبح مملا لأنه تكرر كل يوم تيقنا أن الطعام كان روسيا لأن الفندق ومصر عموما مليئة بالروس الإحباط الحقيقي الوحيد في هذه العطلة هو أن كل أحواض السباحة الثلاثة كانوا متسخين وخلال عطلتنا بالكامل لم نستطع استخدامهم بالرغم من محاولات الموظفين فقاموا بتنظيف أخواض السباحة لمدة 24 ساعة في اليوم كل يوم لكنهم لم يتمكنوا من تنظيفه',
#  'ممتازة وفعالة فى تخفيف آلام العظام والمفاصل',
#  ...]

# %%
# Step 2   Follow the instructions below

from sklearn.feature_extraction.text import TfidfVectorizer
P = 1000   ## configuration hyperparameter; you can modify it if you want; see instructions below.

## COMPLETE THE CODE BELOW


## Find typical words of the TUN language

# create TfidfVectorizer instance with maxdf = 1.0 so that the most frequent words of the corpus are NOT thrown away
bow_model_tun = TfidfVectorizer (max_df = 1.0, min_df = 0.001)

# call fit() method with our TUN corpus; this will create the vocabulary of the corpus ...
bow_model_tun.fit( tun_corpus_clean_train )

# select P words from this vocabulary that have the SMALLEST IDF values -- See the source code in TD1 for help ...
print(len(bow_model_tun.get_feature_names ()))
tfidf_vocab=bow_model_tun.get_feature_names ()

typical_words_tun =pd.DataFrame(dict(Word=tfidf_vocab,IDF=bow_model_tun.idf_)).sort_values("IDF", inplace=False, ascending = True ).head(1000)

# Note: we do not need to create the DTM matrix in this part.


## Find typical words of the ARA language: repeat same steps as above.

# call fit() method with our TUN corpus; this will create the vocabulary of the corpus ...
bow_model_ara = TfidfVectorizer (max_df = 1.0, min_df = 0.001)
bow_model_ara.fit( ara_corpus_clean_train )

# select P words from this vocabulary that have the SMALLEST IDF values -- See the source code in TD1 for help ...
print(len(bow_model_ara.get_feature_names ()))
tfidf_vocab=bow_model_ara.get_feature_names ()

typical_words_ara =pd.DataFrame(dict(Word=tfidf_vocab,IDF=bow_model_ara.idf_)).sort_values("IDF", inplace=False, ascending = True).head(1000)

print(typical_words_ara)
print(typical_words_tun)
# Out:
# 1438
# 6717
#            IDF       Word
# 5416  1.470997         من
# 4346  1.633383         في
# 4134  1.953434        على
# 3119  2.034623        جدا
# 1703  2.112529     الفندق
# 4471  2.395595        كان
# 5665  2.428918        هذا
# 4586  2.429478         لا
# 4321  2.476813       فندق
# 4930  2.541743         ما
# 4515  2.576185         كل
# 5262  2.608834         مع
# 4473  2.628128       كانت
# 280   2.648149         أن
# 3497  2.656552       رائع
# 357   2.705184        إلى
# 3196  2.708512        جيد
# 4164  2.793909         عن
# 1663  2.817996      الغرف
# 5675  2.818410       هناك
# 4857  2.910130         لم
# 4355  2.995207        فيه
# 5352  3.007617       مكان
# 6299  3.029330       ولكن
# 5680  3.056757         هو
# 4376  3.062017        قبل
# 3316  3.093630        حيث
# 1047  3.131915       التي
# 2245  3.142720         ان
# 2724  3.143292         به
# ...        ...        ...
# 6655  5.838834     يقومون
# 649   5.838834         ال
# 3134  5.838834       جربت
# 338   5.847345     إضافية
# 4726  5.847345        لكي
# 326   5.847345      إدارة
# 103   5.847345      أحببت
# 1252  5.847345       الذى
# 715   5.847345    الأعمال
# 1414  5.847345    السيارة
# 4649  5.847345      لدرجة
# 6317  5.847345        ولو
# 2068  5.847345     الممكن
# 2882  5.847345       تدفع
# 4685  5.847345      لطفاء
# 4399  5.855929      قريبا
# 5525  5.855929       نادي
# 4741  5.855929      للاسف
# 2562  5.855929        برج
# 1013  5.855929  التعليقات
# 4329  5.855929       فهذا
# 1368  5.855929      السطح
# 3628  5.855929         زي
# 4043  5.855929     عائلتي
# 267   5.864587       أمام
# 3914  5.864587       صحيح
# 4738  5.864587  للاسترخاء
# 6218  5.864587     وغيرها
# 5690  5.864587     هيلتون
# 2248  5.864587        انت
#
# [1000 rows x 2 columns]
#            IDF     Word
# 892   2.470936       في
# 1160  2.918870       من
# 1357  2.989192       يا
# 819   3.097158      علي
# 242   3.310686     الله
# 1038  3.392924       ما
# 651   3.453143      ربي
# 986   3.625856       لا
# 288   3.713165      الي
# 505   3.905917     تونس
# 945   3.930067      كان
# 1263  4.109726      هذا
# 1275  4.109726       هه
# 1294  4.136681    والله
# 956   4.161579       كل
# 310   4.210369      انت
# 309   4.267874      انا
# 821   4.440893     عليك
# 363   4.533983    برافو
# 898   4.562851      فيه
# 1276  4.588276       هو
# 557   4.592577      حتي
# 1146  4.592577      ملا
# 342   4.596897      باش
# 1126  4.609969       مع
# 308   4.659417       ان
# 1042  4.664036     ماسط
# 110   4.668677  التونسي
# 1193  4.696981      موش
# 369   4.696981     برشا
# ...        ...      ...
# 148   7.400257    الدور
# 170   7.400257   السيدة
# 896   7.400257     فيلم
# 881   7.400257       فم
# 249   7.474365  المثلية
# 1370  7.474365      يجب
# 476   7.474365    تعليق
# 695   7.474365     سعدك
# 1274  7.474365      هما
# 166   7.474365   السلام
# 1366  7.474365     يبدا
# 96    7.474365   البنات
# 706   7.474365   سيتكوم
# 708   7.474365     سيدة
# 1319  7.474365    وشكرا
# 1099  7.474365     مرزن
# 224   7.474365   القاضي
# 1358  7.474365      ياا
# 226   7.474365   القران
# 606   7.474365     خمسة
# 1120  7.474365     مشاء
# 1057  7.474365     مبدع
# 1123  7.474365     مشيت
# 1285  7.474365     واضح
# 615   7.474365      دار
# 511   7.474365       ثم
# 1345  7.474365     وملا
# 593   7.474365     خاتر
# 618   7.474365     دخلت
# 160   7.474365  الرذيلة
#
# [1000 rows x 2 columns]

# %%
# Step 3 -- write the algorithm for dictionary-based language identification. 
#    This algorithm selects the language that has the highest number of typical words in the input document.

## COMPLETE THE CODE BELOW

def dict_langid(typical_words,doc):
    s=0
    l=doc.split(" ")
    for i in typical_words:
         if i in l:
                s=s+1
    k=len(doc.split(" "))
    float(s)
    Frac=float(s/k)                
    return Frac

# for each document in the test combined test corpus, call dict_langid with typical_words_tun and then with typical_words_tun
dict_langid(["Hello"], "Hello Guys How  are you ")
# l="Hello Guys How  are you ".split(" ")
# "Hello" in l
# len(l)
ARAS=[]


ARA=typical_words_ara['Word'].tolist()
TUN=typical_words_tun['Word'].tolist()
print(dict_langid(ARA, doc))
print(dict_langid(TUN, doc))
# .
for i in small_corpus:
    S=[]
    S.append(i)
    if (dict_langid(ARA, i)>dict_langid(TUN, doc)):
        S.append('ARA')
    else:
        S.append('TUN')
    ARAS.append(S)
# Out:
# 0.43478260869565216
# 0.17391304347826086

# %%
pd.DataFrame(ARAS)
# Out:
#                                                       0    1
# 0     بل الف نجمه ع هالعبه انصح كل من يحب الدقه والس...  ARA
# 1     منتج ممتاز وتغليف رائع وصوت نقي مميز وواضح وقو...  ARA
# 2     فندق hellzooaaguara الأسوأ أننا جربنا ثلاث غرف...  ARA
# 3     انا جربتهم بتنظيف الاسنان ومانو بصراحة يجننو ب...  ARA
# 4     بصراحة قاعة الافراح لم تعجبني بسبب انها موزعة ...  ARA
# 5     موقع متوسط و غرف متوسطة لقد مكثت في هذا الفندق...  ARA
# 6     جيد جدا حديقة الحيوان مسلية جدا شوفت فيه الحيو...  ARA
# 7     النظافة عنوانهم ابد ما قد شفت نظافة مثل النظاف...  ARA
# 8     فندق جميل جدا في أسوان لقد مكثنا في هذا الفندق...  ARA
# 9     طبعا الكل بعرف كيف كان الطازج من أول ما فتح كل...  ARA
# 10    علبه الساعة دائما تغلف بشريط لاصق لونه بني وهو...  ARA
# 11                          قريبة من البيت واسعاها جيدة  ARA
# 12    حلو اذا كان غير مزحوم فندق رائع من حيث الموقع ...  ARA
# 13    ممتاز فندق عظيم غرفه نظيفة والطاقم ودود جد ا و...  ARA
# 14    يبيع اللوحات الفنية و البراويز و غيرها من الأش...  ARA
# 15    لم يعجبني وكان ينبغي أن يكون مع ساندويتش بـ 20...  ARA
# 16    اسوأ فندق رحته فى حياتى والله بدون مبالغه دا ا...  ARA
# 17    قبل سنة واحدة مطعم يعد الافضل بين المطاعم السو...  ARA
# 18    فندق لطيف الموقع رائع فريق العمل معظمه متعاون ...  ARA
# 4997  في البداية وجدت صعوبة في تحديد اللغة ثم بات كل...  ARA
# 4998  موقع رائع وخدمة سيئة اقمت في هذا الفندق يوم وا...  ARA
# 4999  لن أقيم هنا مرة أخرى المقبس الكهربائي في الغرف...  ARA
#
# [5000 rows x 2 columns]

# %%
TUNIS=[]
for i in tun_corpus_clean:
    S=[]
    S.append(i)
    if (dict_langid(ARA, i)>dict_langid(TUN, doc)):
        S.append('ARA')
    else:
        S.append('TUN')
    TUNIS.append(S)
pd.DataFrame(TUNIS)
# Out:
#                                                        0    1
# 0                                        ملا عار يا تونس  ARA
# 1      البرنامج مهواش عاالي بلكل الييتفرجوا عليه يلزم...  ARA
# 2                                   الله يا الله شنو هذا  ARA
# 3                      دون تعليق علي الريق متاع التونسية  ARA
# 4       هذي انسانة فاشلة نجحت بالفساد لتعمل فيه ربي يهدي  TUN
# 5                                 ولاد الهجالة موش مفيدة  TUN
# 6                      ماسط مااسط اكبر ممثل فاشل في تونس  TUN
# 7                                  قولولوا يزي من النفاق  ARA
# 8      تراباوو معادش تعديو تصاور العرا و القرا و قلة ...  TUN
# 9                                     قناتكم عملت الريحة  TUN
# 10     يكب سعدوا انشالله يهلكوا ربي تو هاكا راجل تيي ...  TUN
# 11     انسان حقود مسخ منحط سافل ساقط ماسط تافه نعن زك...  TUN
# 12     نور شيبة بر ا وهف يهز ك و يلم ك جبالك الر واسي...  TUN
# 13               هذا حيوان وليس انسان حتي الشهادة ماشهدش  ARA
# 14     مريض ربي يشفيه التجمع والرجلة ما يتقابلوش يا ق...  ARA
# 15     اكب سعدك ممصتك اووه يا كذاب يا سفيه ملا كوارث ...  ARA
# 16                                       ملا عملة عملتها  TUN
# 17     مية الكسوري كرهتني في البرنامج قبل ما تتكلم نع...  ARA
# 18     يدعي النضال و هو اكبر منافق عدا سنين يضرب في ا...  TUN
# 19     انسان تافه و مهرج لا ع لا قة له لا بالفن و لا ...  TUN
# 20     الحق موش فهالخامجة النكرة الحق في جايبها ومدخل...  TUN
# 21     ياسمير برنامجك فقد الصلوحية بطرية اوفات وسمير ...  ARA
# 22     قدااش ماسط طط متع الوزير في القهوة تكب سعدها تونس  ARA
# 23     حاجة واحدة مفهمتهاش علاش تجيبو فيه في البرامج ...  ARA
# 24             لحاس في وقت بن علي و ستبقي عمرك كولو لحاس  ARA
# 25                              ما تحشمش لعنة الله عليكم  ARA
# 26                            انسان معقد وما عندوش اخلاق  ARA
# 27     امين قارة راك مااسط برشة تتضومر وتهرج تتفورخ م...  ARA
# 28        تافه وماسط وبليد ويقزز وساقط و واطي وتفوه عليه  TUN
# 29     تضحكو عليه وانسيتو الي الطحين في دمو ودم الالا...  ARA
# ...                                                  ...  ...
# 12009                                   ربي يحميك ويعينك  TUN
# 12010               معلم برجولية شكون الراجل الي يتفكرهم  TUN
# 12011  كل عام وانت وكافة الشعب التونسي شيبا وشبابا با...  ARA
# 12012                        bravo كل عام وانتم بالف خير  ARA
# 12013       الله يوافقك لما فيه الخير لكل العباد والبلاد  ARA
# 12014           يعطيه الصحة والعافية وطول العمر في الخير  TUN
# 12015  بالله سيدي الرءيس ربي يبارك لك في كل اعمالك شو...  ARA
# 12016  راجل دولة سي يوسف والله الوحيد الي يخدم بقلب و...  ARA
# 12017  ربي معاك يا معلم راهم سراق الشعب حمزه حسبنا ال...  TUN
# 12018                                  ينصر دينك يا معلم  ARA
# 12019          ربي معاه مجهود كبير يقوم بيه رءيس الحكومة  ARA
# 12020                                 نحبكوك اسد يا شاهد  ARA
# 12021                             واصل هكا يا معلم برافو  ARA
# 12022    ربي يقويك عليهم ما ترحمهمش خل يكونو عبرة لغيرهم  ARA
# 12023                             ربي معاك و ينصرك عليهم  ARA
# 12024                     كل التقدير سيدي الرءيس بي معاك  ARA
# 12025                         ربي يقويك عليهم يا سي يوسف  ARA
# 12026  سي يوسف اعمل طلة علي الفريقوات الي محتكرة الدن...  ARA
# 12027  احسنت ثم شكرا لك كلام صحيح و يلزم مراجعة الشها...  ARA
# 12028  انت يا سي يوسف الشاهد صادق وعندي فيك الثقة الك...  ARA
# 12029  واحنا ما نشكوش في ارادتك وارادة الوطنيين ربي م...  ARA
# 12030  يعطيك الصحة ياولدي ربي معاك و يعينك وبرك الله ...  ARA
# 12031  ربي معاك ويرعاك والشعب ايضا معاك ويساندك ولكن ...  ARA
# 12032  اربي كريم ونت من خيرة ما انجبت تونس فبحيث ربي ...  ARA
# 12033  نحن نشد علي اياديكم سيدي الكريم ربي معاكم وان ...  ARA
# 12034  برا ربي معاك اعدل وتوكل علي الله تربح اضرب الك...  TUN
# 12035  انا حسيتك صادق في كلامك ان شاء الله م تخيب ظني...  ARA
# 12036  الله يعطيك الصحه والعافيه اخي الكريم وبارك الل...  ARA
# 12037      يعطيك الصحه ياسي الشاهد كل بلاد تخدمها رجالها  TUN
# 12038  بالحق بكل معني الكلمة نحب هالشخصية السياسية عل...  TUN
#
# [12039 rows x 2 columns]

# %%
# Step 4
# Reference: see scikit-learn documentation

## COMPLETE THE CODE BELOW

from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, precision_score, recall_score

# %% [markdown]
# ## Construct a language classifier using supervised learning
# - **Step 0**: Divide each corpus into a training corpus (70%) and test corpus (30%).
# - **Step 1**: Create a data frame called ``train_df`` that has two columns: 'document' and 'language'. The 'document' column contains the two corpora concatenated together. The values in the '' column should be 'TUN' and 'ARA'.  Repeat the same thing for the ``test_df``.
# - **Step 2**: Convert the training documents into numeric feature vectors using the BOW-tfidf method with **character ngrams**.
# - **Step 3**: Create a language classifier using Naive Bayes method (tfidf version).
# - **Step 4**: Evaluate performance of this classifier based on the test corpus -- calculate classification accuracy, precision, recall, F1, and confusion matrix.

# %% [markdown]
# ### EXERCISE 6
# Implement each step by carefully following the instructions above.

# %%
# Step 0 just use the same variables that you created in Step 1 of the previous part.
# Nothing to do
tun_corpus_clean_train, tun_corpus_clean_test = train_test_split(tun_corpus_clean,test_size=0.3 )
ara_corpus_clean_train, ara_corpus_clean_test = train_test_split(ara_corpus_clean,test_size=0.3)

# %%
# Step 1   create 2 data frames called train_df and test_df (as explained above)

## COMPLETE THE CODE BELOW

# create data frame
train_df = pd.DataFrame({'document':[], 'language':[]})
test_df = pd.DataFrame({'document':[], 'language':[]})
# fill the language column
train_df.language = pd.Series(['TUN']*len(tun_corpus_clean_train) + ['ARA']*len(ara_corpus_clean_train))
test_df.language = pd.Series(['TUN']*len(tun_corpus_clean_test) + ['ARA']*len(ara_corpus_clean_test))


# fill the document column -- CONCATENATE the TUN CORPUS and ARA CORPUS

train_df.document = pd.DataFrame(tun_corpus_clean_train+ara_corpus_clean_train) 
test_df.document=pd.DataFrame(tun_corpus_clean_test+ara_corpus_clean_test)

train_df.head()
test_df.head()
# Out:
#                                             document language
# 0              يا بيه ايجا للبيرو نعلمك كيفاه تسوقها      TUN
# 1  حصة في القمة منشط في القمة احنا نحبوها في الجز...      TUN
# 2                                  شنوا ها لحالة هدي      TUN
# 3                  رجل دين رغم انف المخنثين الشمسيين      TUN
# 4                                    ربي يفظلك لميمة      TUN

# %%
# verify that the number of rows in this data frame = sum of the number of documents in each corpus.  
assert(train_df.shape[0] == len(tun_corpus_clean_train) + len(ara_corpus_clean_train))
assert(train_df.shape[1] == 2)

# %%
assert((train_df.language.nunique() == 2) and (list(train_df.language.unique()) == ['TUN', 'ARA']))

# %%
# Step 2  Convert the training documents into numeric feature vectors using the BOW-tfidf method with character ngrams.

## COMPLETE THE CODE BELOW

n =3   # hyperparameter for of character ngrams ; you can change it if you want but n=3 is a reaonable value ...

# Create an instance of TfidfVectorizer class with analyzer = 'char' so that it generates bag of characters and not bag of words
bow_model_char = TfidfVectorizer(analyzer='char', ngram_range=(1,n), max_df = 0.5, min_df=0.1 )
,
# Call fit method with the combined training corpus
bow_model_char.fit(list(train_df['document']))

# Create DTM matrix of the combined training corpus and test corpus

X=bow_model_char.transform(train_df.document)
Y=bow_model_char.transform(test_df.document)
X.shape
# Out:
# (23332, 649)

# %%
# Step 3   -- see official documentation of MultinomialNB in scikit-learn

from sklearn.naive_bayes import MultinomialNB

nb_model = MultinomialNB()

nb_model.fit(X,list(train_df['language']))

# nb_model.predict(bow_model_char.transform(["البهيم"]))
# bow_model_char.transform(["hajalam"])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
nb_model.predict_proba(bow_model_char.transform(["الناس تكبر تعقال..و هذوما يكبرو يزيدو يخشوا الخلاء"]))
# Out:
# array([[0.23, 0.77]])

# %%
nb_model.score(X,list(train_df['language']))
# Out:
# 0.9336104920281159

# %%
nb_model.predict(bow_model_char.transform(["الناس تكبر تعقال..و هذوما يكبرو يزيدو يخشوا الخلاء"]))
# Out:
# array(['TUN'], dtype='<U3')

# %%
nb_model.score(Y,list(test_df['language']))
# Out:
# 0.9303

# %%
# Step 4   Use the same source code as in Step 4 of the previous part.
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, precision_score, recall_score

# %%
accuracy_score(test_df['language'],nb_model.predict(Y))
# Out:
# 0.9303

# %%
confusion_matrix(test_df['language'],nb_model.predict(Y))
# Out:
# array([[6117,  271],
#        [ 426, 3186]])

# %%
f1_score(test_df['language'],nb_model.predict(Y),average=None)
# Out:
# array([0.946, 0.901])

# %%
precision_score(test_df['language'],nb_model.predict(Y),pos_label='ARA')
# Out:
# 0.9348922512608895
